# %%
using CSV, DataFrames, JuMP, Gurobi
states = CSV.read("blackjack_states.csv", DataFrame)
# Out:
# 380×3 DataFrame
#  Row │ Player  Dealer  Ace
#      │ Int64   Int64   Int64
# ─────┼───────────────────────
#    1 │     20      10      0
#    2 │     14      10      0
#    3 │      9      10      0
#    4 │     15       4      0
#    5 │     19       4      1
#    6 │     24       4      0
#    7 │     14       4      0
#    8 │     18       9      0
#   ⋮  │   ⋮       ⋮       ⋮
#  374 │     30       9      0
#  375 │     15       4      1
#  376 │     12       3      1
#  377 │     13       9      1
#  378 │     12       9      1
#  379 │      4       8      0
#  380 │     31       1      0
#              365 rows omitted

# %%
outcomes = CSV.read("blackjack_outcomes.csv", DataFrame)
# Out:
# 380×2 DataFrame
#  Row │ Stick       Hit
#      │ Float64     Float64
# ─────┼────────────────────────
#    1 │  0.43951    -0.822925
#    2 │ -0.645442   -0.527615
#    3 │ -0.51582    -0.152714
#    4 │ -0.208322   -0.397723
#    5 │  0.293247    0.15401
#    6 │  0.0         0.0
#    7 │ -0.148713   -0.416305
#    8 │ -0.129535   -0.648893
#   ⋮  │     ⋮           ⋮
#  374 │  0.0         0.0
#  375 │ -0.169342    0.0480908
#  376 │ -0.0202266   0.0890556
#  377 │ -0.455884   -0.026202
#  378 │ -0.240575    0.0391451
#  379 │ -0.239346   -0.163799
#  380 │  0.0         0.0
#               365 rows omitted

# %%
grid_opt = IAI.GridSearch(
    IAI.OptimalTreePolicyMaximizer(
        random_seed=15095,
    ),
    max_depth=1:4
)
IAI.fit_cv!(grid_opt, )
