# %%
import pandas as pd

# %%
states = pd.read_csv("lunar_lander_states_retrained.csv")

# %%
outcomes = pd.read_csv("lunar_lander_outcomes_retrained.csv")

# %%
sampled_states = states.sample(25_000, replace=False)
sampled_outcomes = outcomes.loc[sampled_states.index]

# %%
sampled_states.to_csv("lunar_lander_states_subset.csv", index=False)
sampled_outcomes.to_csv("lunar_lander_outcomes_subset.csv", index=False)

# %%
# active_inds = ((states["left_contact"] + states["right_contact"]) < 2)

# %%
# active_states = states.loc[active_inds]
# inactive_states = states.loc[~active_inds]
# active_outcomes = outcomes.loc[active_inds]

# %%
# sampled_active_states = active_states.sample(49_000, replace=False)
# sampled_active_outcomes = active_outcomes.loc[sampled_active_states.index]

# %%
# sampled_inactive_states = inactive_states.sample(1_000, replace=False)
# sampled_inactive_outcomes = pd.DataFrame(index=sampled_inactive_states.index, columns=outcomes.columns)
# sampled_inactive_outcomes.loc[:] = 0.
# sampled_inactive_outcomes["Nothing"] = 1.

# %%
# all_states = pd.concat((sampled_active_states, sampled_inactive_states), axis=0)
# all_outcomes = pd.concat((sampled_active_outcomes, sampled_inactive_outcomes), axis=0)

# %%
# all_states.to_csv("lunar_lander_states_subset.csv", index=False)
# all_outcomes.to_csv("lunar_lander_outcomes_subset.csv", index=False)
